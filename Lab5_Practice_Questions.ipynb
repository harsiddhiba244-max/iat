# %% [markdown]
# # Lab 5 (Continued): Global Alcohol Consumption - Practice Questions

# %% [markdown]
# **Q9: Which continent drinks the least beer on average?**

# %% [markdown]
# **Q10: Find the total (sum) of all alcohol servings for each continent (all columns).**

# %% [markdown]
# **Q11: Which country has the highest beer_servings in the entire dataset?**

# %% [markdown]
# **Q12: Which country has the highest wine_servings in the entire dataset?**

# %% [markdown]
# **Q13: How many countries are there in each continent? (Use value_counts or groupby size)**

# %% [markdown]
# **Q14: Find the standard deviation of spirit_servings for each continent.**

# %% [markdown]
# **Q15: Sort the countries by total_litres_of_pure_alcohol in descending order and display the top 10 countries.**

# %% [markdown]
# **Q16: Filter and display all countries where beer_servings is greater than 200.**

# %% [markdown]
# **Q17: Find the correlation between beer_servings and wine_servings.**

# %% [markdown]
# **Q18: Find the overall mean, minimum, and maximum of total_litres_of_pure_alcohol for the whole dataset (not grouped by continent).**
