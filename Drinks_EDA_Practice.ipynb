# %% [markdown]
# # Exploratory Data Analysis on World Alcohol Consumption using Pandas
#
# Practice worksheet — answer each question in the empty code cell below it.

# %% [markdown]
# **1. Import the necessary libraries.**

# %% [markdown]
# **2. Import the dataset from this address.**
#
# https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/drinks.csv

# %% [markdown]
# **3. Assign it to a variable called `drinks` and use `country` as the index.**

# %% [markdown]
# **4. Display the first 20 entries.**

# %% [markdown]
# **5. Display the last 15 entries.**

# %% [markdown]
# **6. What is the number of observations in the dataset?**

# %% [markdown]
# **7. What is the number of columns in the dataset?**

# %% [markdown]
# **8. Print the name of all the columns.**

# %% [markdown]
# **9. How is the dataset indexed?**

# %% [markdown]
# **10. What is the data type of each column?**

# %% [markdown]
# **11. Print only the `continent` column.**

# %% [markdown]
# **12. How many different continents are in this dataset?**

# %% [markdown]
# **13. What is the most frequent continent?**

# %% [markdown]
# **14. Summarize the DataFrame.**

# %% [markdown]
# **15. Summarize all the columns.**

# %% [markdown]
# **16. Summarize only the `continent` column.**

# %% [markdown]
# **17. What is the mean total litres of pure alcohol consumed?**

# %% [markdown]
# **18. What is the beer servings value with the least occurrence?**

# %% [markdown]
# **19. Print only the `beer_servings` column.**

# %% [markdown]
# **20. How many countries are there for each continent?**

# %% [markdown]
# **21. What is the most frequent value in the `wine_servings` column?**

# %% [markdown]
# **22. How many different values are there in the `spirit_servings` column?**

# %% [markdown]
# **23. Summarize only the `wine_servings` column.**

# %% [markdown]
# **24. What is the maximum `total_litres_of_pure_alcohol` value in the dataset?**

# %% [markdown]
# **25. What is the minimum `total_litres_of_pure_alcohol` value in the dataset?**

# %% [markdown]
# **26. What is the median `beer_servings` across all countries?**

# %% [markdown]
# **27. Print only the `spirit_servings` column.**

# %% [markdown]
# **28. What is the mean `wine_servings` across all countries?**

# %% [markdown]
# **29. What is the maximum `beer_servings` value in the dataset?**

# %% [markdown]
# **30. What is the minimum `beer_servings` value in the dataset?**

# %% [markdown]
# **31. What are the unique values in the `continent` column?**

# %% [markdown]
# **32. What is the maximum `spirit_servings` value in the dataset?**

# %% [markdown]
# **33. What is the minimum `spirit_servings` value in the dataset?**

# %% [markdown]
# **34. What is the most frequent value in the `total_litres_of_pure_alcohol` column?**

# %% [markdown]
# **35. What is the median `total_litres_of_pure_alcohol` across all countries?**

# %% [markdown]
# **36. Print the shape of the dataset.**

# %% [markdown]
# **37. Print the first 5 entries of only the `beer_servings` column.**

# %% [markdown]
# **38. What is the median `wine_servings` across all countries?**
