# %% [markdown]
# # Pandas Practice Questions - LAB-2, LAB-3, LAB-4
# ## Introduction to Advanced Technologies (2304CS501)
# ### Darshan University - B.Sc. (IT)
#
# **Dataset:** User Demographics (u.user)
#
# **Instructions:**
# - Answer each question in the corresponding code cell
# - Use only Pandas and standard Python libraries
# - Refer to the lab manual for guidance
#
# ---

# %% [markdown]
# ## Section 1: Data Loading and Exploration (LAB-2 Questions)
#
# ### Question 1
# Import the necessary libraries (pandas, numpy, matplotlib) and load the user demographics dataset from the URL:
# `https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user`
#
# Assign it to a variable called `users` and use 'user_id' as the index.

# %% [markdown]
# ### Question 2
# Display the first 20 rows of the dataset using the appropriate method.

# %% [markdown]
# ### Question 3
# Display the last 8 rows of the dataset.

# %% [markdown]
# ### Question 4
# What is the shape of the dataset? Print the number of rows and columns.

# %% [markdown]
# ### Question 5
# Print the column names and their data types of the dataset.

# %% [markdown]
# ### Question 6
# Display basic statistical information about the dataset using the `.info()` method.

# %% [markdown]
# ### Question 7
# Extract and display only the 'age' column.

# %% [markdown]
# ### Question 8
# Extract and display only the 'occupation' and 'gender' columns.

# %% [markdown]
# ### Question 9
# How many unique occupations are in the dataset? List them.

# %% [markdown]
# ### Question 10
# What is the most frequent occupation in the dataset?

# %% [markdown]
# ### Question 11
# Display a summary of the entire DataFrame using `.describe()`.

# %% [markdown]
# ### Question 12
# What is the mean age of users in the dataset?

# %% [markdown]
# ### Question 13
# What is the median age of users?

# %% [markdown]
# ### Question 14
# What is the age range (min and max age) of users in the dataset?

# %% [markdown]
# ## Section 2: Series Operations and Time Series (LAB-3 Questions)

# %% [markdown]
# ### Question 15
# Create a Pandas Series from the 'age' column and perform the following:
# - Add 5 to each age value
# - Multiply the result by 2
# - Display the first 10 results

# %% [markdown]
# ### Question 16
# Create a Series with custom index labels from the occupation column and display its properties.

# %% [markdown]
# ### Question 17
# Create a time series starting from January 1st, 2024 with a frequency of 1 day for the length of the dataset. Display the first 10 dates.

# %% [markdown]
# ### Question 18
# Create a Series with:
# - Data: User ages
# - Index: User IDs from the dataset
# - Name: 'User_Ages'
#
# Display this Series and check its dtype.

# %% [markdown]
# ## Section 3: DataFrame Manipulation (LAB-4 Questions)

# %% [markdown]
# ### Question 19
# Create a new DataFrame from a dictionary with the following structure:
# - Keys: 'name', 'age', 'occupation', 'gender', 'zip_code'
# - Create at least 5 sample records
#
# Assign it to a variable called `sample_users`.

# %% [markdown]
# ### Question 20
# Reorder the columns in `sample_users` as: 'name', 'gender', 'age', 'occupation', 'zip_code'.
#
# Display the reordered DataFrame.

# %% [markdown]
# ### Question 21
# Add a new column called 'city' to `sample_users` and insert values like 'Ahmedabad', 'Mumbai', 'Bangalore', etc.

# %% [markdown]
# ### Question 22
# Display the data types of each column in the `sample_users` DataFrame.

# %% [markdown]
# ### Question 23
# Filter the original `users` dataset to find all users with:
# - Age greater than 30
# - Occupation as 'student'
#
# Display the count and first 5 results.

# %% [markdown]
# ---
#
# ## Summary
#
# **Topics Covered:**
# - ✓ Data loading from URLs
# - ✓ DataFrame exploration and indexing
# - ✓ Column selection and filtering
# - ✓ Data aggregation and statistics
# - ✓ Series operations and arithmetic
# - ✓ Time series creation
# - ✓ DataFrame creation and manipulation
# - ✓ Column reordering and addition
#
# **Dataset Information:**
# - Source: MovieLens dataset
# - Columns: user_id, age, gender, occupation, zip_code
# - Total Records: 943 users
