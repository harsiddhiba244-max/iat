# %% [markdown]
# # Pandas Practice: Creating and Manipulating a DataFrame
#
# ### Employee Dataset
#
# Answer the following questions using the Pandas library. Write your code in the empty cell provided below each question.

# %% [markdown]
# **Q1. Import the necessary libraries. (A)**

# %% [markdown]
# **Q2. Create a data dictionary with the keys: `emp_id`, `name`, `department`, `salary`, `email`. (A)**

# %% [markdown]
# **Q3. Convert the dictionary into a DataFrame and assign it to a variable called `employee`. (A)**

# %% [markdown]
# **Q4. Reorder the columns of `employee` as: `name`, `department`, `emp_id`, `salary`, `email`. (B)**

# %% [markdown]
# **Q5. Add another column called `city` and insert any values you like. (B)**

# %% [markdown]
# **Q6. Display the data types of each column in the `employee` DataFrame. (B)**
