# %% [markdown]
# # Dataset Exploration Practical

# %%
import pandas as pd

df = pd.read_csv('dataset.csv')

# %% [markdown]
# ## Level A – Basic Dataset Exploration

# %% [markdown]
# **Q1.** What are the dimensions of the dataset?

# %% [markdown]
# **Q2.** How many rows and columns does the dataset have?

# %% [markdown]
# **Q3.** Display rows 5 to 15.

# %% [markdown]
# **Q4.** What is the data type of the 'age' column?

# %% [markdown]
# **Q5.** What is the data type of the 'gender' column?

# %% [markdown]
# **Q6.** Display the first 3 rows of the dataset.

# %% [markdown]
# **Q7.** Display the last 5 rows of the dataset.

# %% [markdown]
# **Q8.** What is the column name at index 2?

# %% [markdown]
# **Q9.** List all column names in order.

# %% [markdown]
# **Q10.** Is 'zip_code' a column in the dataset?

# %% [markdown]
# ## Level B – Data Filtering & Value Counts

# %% [markdown]
# **Q1.** How many unique genders are there in the dataset?

# %% [markdown]
# **Q2.** What are the unique genders?

# %% [markdown]
# **Q3.** What is the most frequent gender?

# %% [markdown]
# **Q4.** How many unique zip codes exist?

# %% [markdown]
# **Q5.** What is the least frequent occupation?

# %% [markdown]
# **Q6.** How many users have the occupation 'student'?

# %% [markdown]
# **Q7.** How many users are there for the most common occupation?

# %% [markdown]
# **Q8.** Display the top 5 occupations by frequency.

# %% [markdown]
# **Q9.** What is the second most frequent occupation?

# %% [markdown]
# **Q10.** How many null values are in the 'occupation' column?

# %% [markdown]
# ## Level C – Statistical Analysis

# %% [markdown]
# **Q1.** What is the minimum age in the dataset?

# %% [markdown]
# **Q2.** What is the maximum age in the dataset?

# %% [markdown]
# **Q3.** What is the median age of users?

# %% [markdown]
# **Q4.** What is the standard deviation of age?

# %% [markdown]
# **Q5.** What is the variance of age?

# %% [markdown]
# **Q6.** What is the age range (max - min)?

# %% [markdown]
# **Q7.** What is the age at the 75th percentile?

# %% [markdown]
# **Q8.** What is the age at the 25th percentile?

# %% [markdown]
# **Q9.** How many users are older than 30?

# %% [markdown]
# **Q10.** How many users are younger than 25?

# %% [markdown]
# **Q11.** What is the mode (most common age)?

# %% [markdown]
# **Q12.** How many users are exactly 30 years old?

# %% [markdown]
# ## Level D – Advanced Analysis

# %% [markdown]
# **Q1.** What percentage of users are in the 'student' occupation?

# %% [markdown]
# **Q2.** Create a frequency distribution of ages.

# %% [markdown]
# **Q3.** How many occupations have only 1 user?
