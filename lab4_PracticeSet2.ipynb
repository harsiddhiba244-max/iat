# %% [markdown]
# # Pandas Practice (Advanced): Series & DataFrame Operations
#
# ### Employee Dataset
#
# This is an advanced-level question set (15 questions) covering DataFrame creation, indexing, filtering, grouping, aggregation, and more.
# Write your code in the empty cell provided below each question.

# %% [markdown]
# **Q1. Import the necessary libraries (pandas and numpy). (A)**

# %% [markdown]
# **Q2. Create a data dictionary with at least 10 employee records containing the keys: `emp_id`, `name`, `department`, `salary`, `age`, `city`, `join_date`. Convert it into a DataFrame called `employee`. (B)**

# %% [markdown]
# **Q3. Set `emp_id` as the index of the `employee` DataFrame. (B)**

# %% [markdown]
# **Q4. Use `.loc[]` to display the `name`, `department`, and `salary` of employees whose index (emp_id) lies between two values of your choice. (B)**

# %% [markdown]
# **Q5. Use `.iloc[]` to display the first 3 rows and the first 4 columns of the DataFrame. (B)**

# %% [markdown]
# **Q6. Filter and display all employees whose `salary` is greater than the average salary of the company. (C)**

# %% [markdown]
# **Q7. Filter and display employees who belong to the `IT` department AND have a salary above 50,000, using multiple conditions. (C)**

# %% [markdown]
# **Q8. Sort the DataFrame by `salary` in descending order, and then by `name` in ascending order for employees with the same salary. (B)**

# %% [markdown]
# **Q9. Rename the column `emp_id` to `employee_id` and `join_date` to `date_of_joining`. (B)**

# %% [markdown]
# **Q10. Introduce a few missing values (`NaN`) into the `salary` or `age` column, then detect and fill them using an appropriate strategy (e.g., mean or median). (C)**

# %% [markdown]
# **Q11. Use `groupby()` on `department` to calculate the average salary and total number of employees per department. (C)**

# %% [markdown]
# **Q12. Use `apply()` with a lambda function to create a new column `salary_category` that labels employees as `'High'` if salary > 55000, otherwise `'Low'`. (C)**

# %% [markdown]
# **Q13. Use `value_counts()` to display how many employees belong to each department, then use `.describe()` to summarize the numeric columns of the DataFrame. (B)**

# %% [markdown]
# **Q14. Create a second small DataFrame called `bonus` containing `emp_id` and `bonus_amount` for a few employees. Merge it with `employee` using an appropriate join type so that all employees are retained even if they have no bonus record. (C)**

# %% [markdown]
# **Q15. Create a pivot table showing the average salary for each `department`, broken down by `city`. (C)**
