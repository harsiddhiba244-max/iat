# %% [markdown]
# # Practice: Pandas Series and Time Series (Set 2)
# Demonstrate basic operations and time series creation using the Pandas library.

# %% [markdown]
# **1. Import the necessary libraries.**

# %% [markdown]
# **2. Create a Series from a tuple.**

# %% [markdown]
# **3. Accessing elements from a Series using slicing.**

# %% [markdown]
# **4. Performing comparison operations on a Series.**
# - series >20
# - series == 30

# %% [markdown]
# **5. Create a Series with custom index labels using characters (e.g., 'a', 'b', 'c').**

# %% [markdown]
# **6. Create a Series with data, index, and name parameter.**

# %% [markdown]
# **7. Create a Pandas Series using two lists:**
#   - One list for the index labels (months)
#   - One list for the data values (sales figures)

# %% [markdown]
# **8. Creating Time Series using Pandas Series:**
#   - Use `pd.to_datetime()` to create a starting date.
#   - Use `pd.to_timedelta()` to generate a range of dates.
#   - Create a Pandas Series using this date range as the index.

# %% [markdown]
# **9. Create a Series from a dictionary (keys become the index).**

# %% [markdown]
# **10. Check the data type and size of a Series using `.dtype` and `.size`.**

# %% [markdown]
# **11. Modify the value of an element in a Series using its index label.**
# - `s['index want to change'] = new value`

# %% [markdown]
# **12. Use `.head()` and `.tail()` to view the first and last elements of a Series.**

# %% [markdown]
# **13. Check for missing values in a Series using `.isnull()`.**

# %% [markdown]
# **14. Sort a Series by its values using `.sort_values()`.**

# %% [markdown]
# **15. Convert a Series to a list and to a NumPy array.**
# - `my_list = s.tolist()`
# - `my_array = s.to_numpy()`

# %% [markdown]
# **16. Creating Time Series using Pandas Series:**
#   - Use `pd.to_datetime()` to create a starting date.
#   - Use `pd.to_timedelta()` to generate a range of time delta (hours, instead of days).
#   - Add the delta to the starting date to generate a datetime index.
#   - Create a Pandas Series using the datetime index.
