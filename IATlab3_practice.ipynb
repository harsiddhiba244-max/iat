# %% [markdown]
# ### 1. Import the required libraries (pandas and numpy).

# %% [markdown]
# ### 2. Create a Series from a tuple.

# %% [markdown]
# ### 3. Accessing elements from a series using negative indexing and slicing.

# %% [markdown]
# **(a) Access the last element of the series using negative indexing.**

# %% [markdown]
# **(b) Access the last three elements using negative slicing.**

# %% [markdown]
# **(c) Slice the series to get every alternate element (step slicing).**

# %% [markdown]
# **(d) Reverse the entire series using slicing.**

# %% [markdown]
# **(e) Access a range of elements using both positive and negative index together (e.g. from index 1 to -2).**

# %% [markdown]
# ### 4. Performing comparison operations on a series (>, <, ==).

# %% [markdown]
# **(a) Find all elements greater than a given value.**

# %% [markdown]
# **(b) Find all elements less than or equal to a given value.**

# %% [markdown]
# **(c) Check which elements are equal to a specific value and display the boolean series.**

# %% [markdown]
# **(d) Compare two series of the same length element-wise (==) and display the result.**

# %% [markdown]
# **(e) Use the boolean series from a comparison to filter and display only the matching elements from the original series.**

# %% [markdown]
# ### 5. Create a Series with custom index labels using roll numbers.

# %% [markdown]
# ### 6. Create a Series with data, index, and dtype parameters (use dtype='int32').

# %% [markdown]
# ### 7. Create a Pandas Series using two lists:
# ### ▪ One list for the index labels (subject names)
# ### ▪ One list for the data values (marks)

# %% [markdown]
# ### 8. Creating a Time Series using Pandas Series:
# ### ▪ Use pd.to_datetime() to create a starting date.
# ### ▪ Use pd.to_timedelta() to generate a range of time delta (weeks instead of days).
# ### ▪ Add the delta to the starting date to generate a datetime index.
# ### ▪ Create a Pandas Series using the datetime index.

# %% [markdown]
# ### 9. Create a Series from a Python dictionary and observe how keys become the index.

# %% [markdown]
# ### 10. Check for missing values in a Series using isnull() and notnull().
